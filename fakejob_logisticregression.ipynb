# %% [markdown]
# <a href="https://colab.research.google.com/github/johnlaraji1608-collab/fakejob_logisticregression/blob/main/fakejob_logisticregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import RepeatedKFold

# %%
df=pd.read_csv('/content/fake_job_postings.csv.zip')

# %%
cols = ["title", "company_profile", "description", "requirements", "benefits"]
for c in cols:
    df[c] = df[c].fillna("")

# %%
def extract_features(df):
    for c in cols:
        df[c+"_len"] = df[c].apply(lambda x : len(str(x)))
        df[c+"_wc"] = df[c].apply(lambda x : len(str(x.split())))

# %%
extract_features(df)

# %%
df['combined_text'] = df['company_profile'] + " " + df['description'] + " " + df['requirements'] + " " + df['benefits']

n_features = {
    "title" : 100,
    "combined_text" : 500
}

# %%
for c, n in n_features.items():
  t_test=TfidfVectorizer(max_features=n, norm='l2', stop_words = 'english')
  t_test.fit(df[c])

# %%
t_train=np.array(t_test.tansform(df[c]).toarray())
